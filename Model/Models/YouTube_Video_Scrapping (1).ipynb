# %% [markdown]
# # Scrapping Code using Youtube API Key
#
# #### The below code will enable the user to scrape the following meta data from Youtube based on the Keywords added below
#
# + Search_Term
# + Video_URL
# + Video_Title
# + Channel_Name
# + Total_Subscribers
# + Total_Views
# + Total_Likes
# + Total_Dislikes
# + Total_Comments
# + Video_Description
# + Total_times_User_added_to_favorites
# + Video_Length
# + Video_Category
# + Video_Tags
# + Age_Restrictions
# + License
# + Captions_Available
# + Video Comments

# %% [markdown]
# # Part 1 : Created a Dataframe (raw_youtube_data) with the list of URLs and associated Metadata

# %%
# # install necessary librarires if already not available
# !pip install google-api-python-client
# !pip install google-auth-oauthlib
# !pip install isodate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.84.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.21.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.11.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.59.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.20.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.27.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib) (2.17.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.27.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate) (1.16.0)
# Installing collected packages: isodate
# Successfully installed isodate-0.6.1

# %%
# import the necessary libraries
import os
import time
import isodate
import requests
import datetime
import warnings
import google.auth
import pandas as pd
from bs4 import BeautifulSoup
import googleapiclient.errors
import google_auth_oauthlib.flow
import googleapiclient.discovery
warnings.filterwarnings("ignore")
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
# Start the timer
start_time = datetime.datetime.now()

# %%
# Setting up API Key through a project in the Google Developer Console and enable YouTube Data API v3 to get one
os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDqO4jitopmbQEQoEIYVW18bEmYKI4HDdU"
# DEVELOPER_KEY = "AIzaSyAeqZ9sTvWhITtEpv-Z-P3Ropd9fYNlfEs"

# %%
# List of keywords based on which the data has to be scrapped
# keywords = ["stress management",
#             "relaxation techniques",
#             "mindfulness",
#             "Meditation",
#             "Breathing exercises",
#             "Yoga for stress relief",
#             "Guided visualization",
#             "Coping with stress",
#             "Stress relief techniques"]

keywords = [
    "Emotional exhaustion",
    "Stress reduction and burnout",
    "Burnout and emotions",
    "Mindfulness and burnout",
    "Workload management",
    "Emotional well-being techniques",
    "Work-life balance techniques",
    "Depersonalization and burnout",
    "Job satisfaction and burnout",
    "Building empathy in the workplace",
    "Managing workplace cynicism",
    "Resilience building",
    "Empathy and emotional connection",
    "Self-care practices",
    "Personal accomplishment and burnout",
    "Motivation and job satisfaction",
    "Empowerment self at work",
    "Enhancing self-efficacy",
    "Goal setting and achievement",
    "Recognizing achievements and milestones",
    "Fostering growth and development"
]

# %%
#no of videos that needs to be scrapped for each key words
no_of_videos_to_be_scrapped = 30

# %%
# Create a YouTube client instance
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# %%
# Define a function to search for videos based on a query
def search_videos(query):
    request = youtube.search().list(
        part="id",
        maxResults=no_of_videos_to_be_scrapped,
        q=query,
        type="video"
    )
    response = request.execute()
    return response['items']

# %%
def get_video_info(search_results):
    video_info = []
    for search_result in search_results:
        video_id = search_result['id']['videoId']
        video_request = youtube.videos().list(
            part="snippet,statistics,contentDetails,status",
            id=video_id
        )
        video_response = video_request.execute()
        video_title = video_response['items'][0]['snippet']['title']
        channel_title = video_response['items'][0]['snippet']['channelTitle']
        subscriber_count = video_response['items'][0]['statistics'].get('subscriberCount', 0)
        view_count = video_response['items'][0]['statistics']['viewCount']
        like_count = video_response['items'][0]['statistics'].get('likeCount', 0)
        dislike_count = video_response['items'][0]['statistics'].get('dislikeCount', 0)
        comment_count = video_response['items'][0]['statistics'].get('commentCount', 0)
        video_description = video_response['items'][0]['snippet']['description']
        favorite_count = video_response['items'][0]['statistics'].get('favoriteCount', 0)
        video_duration = video_response['items'][0]['contentDetails'].get('duration', 'NA')
        video_category = video_response['items'][0]['snippet'].get('categoryId', 'NA')
        video_tags = video_response['items'][0]['snippet'].get('tags', [])
        age_restricted = video_response['items'][0]['contentDetails'].get('contentRating', {}).get('ytRating', 'NA')
        license = video_response['items'][0]['status'].get('license', 'NA')
        caption_status = video_response['items'][0]['snippet'].get('caption', 'NA')
        video_url = f"https://www.youtube.com/watch?v={video_id}"
        video_data = {
            "Search_Term": keyword, # Add keyword to the video_data dictionary
            "Video_URL": video_url,
            "Video_Title": video_title,
            "Channel_Name": channel_title,
            "Total_Subscribers": subscriber_count,
            "Total_Views": view_count,
            "Total_Likes": like_count,
            "Total_Dislikes": dislike_count,
            "Total_Comments": comment_count,
            "Video_Description": video_description,
            "Total_times_User_added_to_favorites": favorite_count,
            "Video_Length": video_duration,
            "Video_Category": video_category,
            "Video_Tags": video_tags,
            "Age_Restrictions":age_restricted,
            "License": license,
            "Captions_Available": caption_status
        }
        video_info.append(video_data)
    return video_info

# %%
# Create an empty list to store the video information
video_data_list = []

# %%
# Loop through the keywords, search for videos, and store the metadata in the list
for keyword in keywords:
    search_results = search_videos(keyword)
    video_info = get_video_info(search_results)
    for video_data in video_info:
        video_data_list.append(video_data)

# %%
# Create a pandas dataframe from the list of dictionaries
raw_youtube_data = pd.DataFrame(video_data_list)

# %%
# Print the dataframe
raw_youtube_data.head(2)
# Out:
#             Search_Term                                    Video_URL  \
# 0  Emotional exhaustion  https://www.youtube.com/watch?v=tVhEz_jceuU
# 1  Emotional exhaustion  https://www.youtube.com/watch?v=CDvnw8eOjFQ
#
#                                   Video_Title Channel_Name  Total_Subscribers  \
# 0  8 Things That Lead To Emotional Exhaustion     Psych2Go                  0
# 1                7 Signs of Emotional Burnout     Psych2Go                  0
#
#   Total_Views Total_Likes  Total_Dislikes Total_Comments  \
# 0      183411       10798               0            726
# 1     2255329       99671               0           8098
#
#                                    Video_Description  \
# 0  Ever feel like life is stressful every single ...
# 1  Emotional burnout is defined as a negative sta...
#
#   Total_times_User_added_to_favorites Video_Length Video_Category  \
# 0                                   0       PT6M1S             27
# 1                                   0      PT6M14S             27
#
#                                           Video_Tags Age_Restrictions  \
# 0  [emotional exhaustion, 8 Things That Lead To E...               NA
# 1  [emotional burnout, emotional burnout symptoms...               NA
#
#           License Captions_Available
# 0  creativeCommon                 NA
# 1  creativeCommon                 NA

# %%
print("Total number of URL metadata scraped:",
      len(raw_youtube_data))
# Out:
# Total number of URL metadata scraped: 630

# %%
def get_duration(duration):
    # Convert ISO 8601 duration to seconds
    duration_in_seconds = isodate.parse_duration(duration).total_seconds()
    # Convert seconds to hh:mm:ss format
    duration_in_hms = time.strftime('%H:%M:%S',
                                    time.gmtime(duration_in_seconds))
    return duration_in_hms

# %%
def clean_duration(duration_str):
    if 'PT' in duration_str:
        duration = duration_str.replace('PT', '')
        if 'H' in duration:
            hours, duration = duration.split('H')
        else:
            hours = '00'
        if 'M' in duration:
            minutes, duration = duration.split('M')
        else:
            minutes = '00'
        if 'S' in duration:
            seconds = duration.split('S')[0]
        else:
            seconds = '00'
        return f'{hours.zfill(2)}:{minutes.zfill(2)}:{seconds.zfill(2)}'
    else:
        return duration_str

# %%
# apply the clean_duration function to the Video_Length column
raw_youtube_data['Video_Length'] = raw_youtube_data['Video_Length'].apply(clean_duration)

# %%
# Print the modified dataframe with correct time format
raw_youtube_data.head(2)
# Out:
#             Search_Term                                    Video_URL  \
# 0  Emotional exhaustion  https://www.youtube.com/watch?v=tVhEz_jceuU
# 1  Emotional exhaustion  https://www.youtube.com/watch?v=CDvnw8eOjFQ
#
#                                   Video_Title Channel_Name  Total_Subscribers  \
# 0  8 Things That Lead To Emotional Exhaustion     Psych2Go                  0
# 1                7 Signs of Emotional Burnout     Psych2Go                  0
#
#   Total_Views Total_Likes  Total_Dislikes Total_Comments  \
# 0      183411       10798               0            726
# 1     2255329       99671               0           8098
#
#                                    Video_Description  \
# 0  Ever feel like life is stressful every single ...
# 1  Emotional burnout is defined as a negative sta...
#
#   Total_times_User_added_to_favorites Video_Length Video_Category  \
# 0                                   0     00:06:01             27
# 1                                   0     00:06:14             27
#
#                                           Video_Tags Age_Restrictions  \
# 0  [emotional exhaustion, 8 Things That Lead To E...               NA
# 1  [emotional burnout, emotional burnout symptoms...               NA
#
#           License Captions_Available
# 0  creativeCommon                 NA
# 1  creativeCommon                 NA

# %%
# Replace with your own API key
# api_key = "AIzaSyAeqZ9sTvWhITtEpv-Z-P3Ropd9fYNlfEs"

youtube = build('youtube',
                'v3',
                developerKey=DEVELOPER_KEY)

categories_response = youtube.videoCategories().list(
    part='snippet',
    regionCode='US'
).execute()

# %%
# Extract the category IDs and their corresponding names
categories = {}
for category in categories_response['items']:
    categories[category['id']] = category['snippet']['title']

# %%
# Map category IDs to category names
raw_youtube_data['Video_Category'] = raw_youtube_data['Video_Category'].map(categories)

# %%
# Print the modified dataframe with the categories name
raw_youtube_data.head(2)
# Out:
#             Search_Term                                    Video_URL  \
# 0  Emotional exhaustion  https://www.youtube.com/watch?v=tVhEz_jceuU
# 1  Emotional exhaustion  https://www.youtube.com/watch?v=CDvnw8eOjFQ
#
#                                   Video_Title Channel_Name  Total_Subscribers  \
# 0  8 Things That Lead To Emotional Exhaustion     Psych2Go                  0
# 1                7 Signs of Emotional Burnout     Psych2Go                  0
#
#   Total_Views Total_Likes  Total_Dislikes Total_Comments  \
# 0      183411       10798               0            726
# 1     2255329       99671               0           8098
#
#                                    Video_Description  \
# 0  Ever feel like life is stressful every single ...
# 1  Emotional burnout is defined as a negative sta...
#
#   Total_times_User_added_to_favorites Video_Length Video_Category  \
# 0                                   0     00:06:01      Education
# 1                                   0     00:06:14      Education
#
#                                           Video_Tags Age_Restrictions  \
# 0  [emotional exhaustion, 8 Things That Lead To E...               NA
# 1  [emotional burnout, emotional burnout symptoms...               NA
#
#           License Captions_Available
# 0  creativeCommon                 NA
# 1  creativeCommon                 NA

# %%
def get_subscriber_count(channel_name, api_key):
    # Construct the API request URL
    url = f"https://www.googleapis.com/youtube/v3/channels?part=statistics&forUsername={channel_name}&key={api_key}"

    # Send the API request
    response = requests.get(url)

    # Check if the API request was successful
    if response.status_code != 200:
        print(f"Error: API request failed with status code {response.status_code}")
        return None

    # Parse the API response
    response_dict = response.json()

    # Check if the response contains the expected keys
    if "items" not in response_dict or len(response_dict["items"]) == 0 or "statistics" not in response_dict["items"][0]:
        print(f"Error: API response is missing expected keys for channel {channel_name}")
        return None

    # Extract the subscriber count from the channel's statistics
    subscriber_count = int(response_dict["items"][0]["statistics"]["subscriberCount"])

    return subscriber_count

# %%
# Iterate through each row in the dataframe and update the Total_Subscribers column
for index, row in raw_youtube_data.iterrows():
    channel_name = row["Channel_Name"]
    subscriber_count = get_subscriber_count(channel_name, DEVELOPER_KEY)
    if subscriber_count is not None:
        raw_youtube_data.at[index, "Total_Subscribers"] = subscriber_count
    else:
        raw_youtube_data.at[index, "Total_Subscribers"] = "unknown"
# Out:
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Steven Furtick
# Error: API response is missing expected keys for channel Dr Julie
# Error: API response is missing expected keys for channel Nena Lavonne, Psy.M.
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel The Chocolate Therapist
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Psychology Element
# Error: API response is missing expected keys for channel The Vine
# Error: API response is missing expected keys for channel nicole on feels
# Error: API response is missing expected keys for channel TopThink
# Error: API response is missing expected keys for channel CV Outreach
# Error: API response is missing expected keys for channel Kati Morton
# Error: API response is missing expected keys for channel Kristin Coaching
# Error: API response is missing expected keys for channel Sarah Pacaro
# Error: API response is missing expected keys for channel Buddhist Society of Western Australia
# Error: API response is missing expected keys for channel MSNBC
# Error: API response is missing expected keys for channel Paul Scanlon
# Error: API response is missing expected keys for channel All Nations Worship Assembly Atlanta
# Error: API response is missing expected keys for channel Dr. K. N. Jacob
# Error: API response is missing expected keys for channel Elevation Church
# Error: API response is missing expected keys for channel Saddleback Church
# Error: API response is missing expected keys for channel BBC Ideas
# Error: API response is missing expected keys for channel The Burnout Doc
# Error: API response is missing expected keys for channel WorkCare
# Error: API response is missing expected keys for channel Mayo Clinic
# Error: API response is missing expected keys for channel Autism From The Inside
# Error: API response is missing expected keys for channel Demystifying Medicine McMaster
# Error: API response is missing expected keys for channel Wellness Orbit by Conscious Initiative PLC
# Error: API response is missing expected keys for channel Therapy in a Nutshell
# Error: API response is missing expected keys for channel Therapy in a Nutshell
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel THE BEAT by Allen Parr
# Error: API response is missing expected keys for channel Andrew Huberman
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel JBI
# Error: API response is missing expected keys for channel Motivation2Study
# Error: API response is missing expected keys for channel TED-Ed
# Error: API response is missing expected keys for channel Mark Hyman, MD
# Error: API response is missing expected keys for channel SciShow Psych
# Error: API response is missing expected keys for channel Wellness Orbit by Conscious Initiative PLC
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Penn State PRO Wellness
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Sleep Easy Relax - Keith Smith
# Error: API response is missing expected keys for channel Kati Morton
# Error: API response is missing expected keys for channel American Medical Association (AMA)
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel How to ADHD
# Error: API response is missing expected keys for channel Dan Sfera
# Error: API response is missing expected keys for channel ADHD Mastery
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Nena Lavonne, Psy.M.
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel University of California Television (UCTV)
# Error: API response is missing expected keys for channel TopThink
# Error: API response is missing expected keys for channel Sukie Baxter - Whole Body Revolution
# Error: API response is missing expected keys for channel Dr Julie
# Error: API response is missing expected keys for channel BBC Ideas
# Error: API response is missing expected keys for channel TED
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Steven Furtick
# Error: API response is missing expected keys for channel Dr Julie
# Error: API response is missing expected keys for channel Demystifying Medicine McMaster
# Error: API response is missing expected keys for channel Dr Julie
# Error: API response is missing expected keys for channel VASTXLXRDE - Topic
# Error: API response is missing expected keys for channel BehindTheScience
# Error: API response is missing expected keys for channel OKclarity - Jewish Mental Health & Wellness
# Error: API response is missing expected keys for channel APOVABIN
# Error: API response is missing expected keys for channel Stephanie Lyn Coaching
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Saddleback Church
# Error: API response is missing expected keys for channel Icahn School of Medicine
# Error: API response is missing expected keys for channel Psychedology
# Error: API response is missing expected keys for channel Kristin Coaching
# Error: API response is missing expected keys for channel Kati Morton
# Error: API response is missing expected keys for channel tom nickel
# Error: API response is missing expected keys for channel Dr. David Geier
# Error: API response is missing expected keys for channel Google for Creators
# Error: API response is missing expected keys for channel A Modern Therapist
# Error: API response is missing expected keys for channel Doc Snipes
# Error: API response is missing expected keys for channel Elizabeth Vaughn
# Error: API response is missing expected keys for channel Instituto Iberoamericano de Estudios para la Paz
# Error: API response is missing expected keys for channel Justme.family
# Error: API response is missing expected keys for channel Hackney Carers Centre
# Error: API response is missing expected keys for channel Mindfulness Meditation by Soothing Pod
# Error: API response is missing expected keys for channel Mindfulness Meditation by Soothing Pod
# Error: API response is missing expected keys for channel OneOp
# Error: API response is missing expected keys for channel HNECC PHN
# Error: API response is missing expected keys for channel Jenna McDowell
# Error: API response is missing expected keys for channel Rituals Cosmetics Global
# Error: API response is missing expected keys for channel SAEM
# Error: API response is missing expected keys for channel Headspace
# Error: API response is missing expected keys for channel KMTV 3 News Now
# Error: API response is missing expected keys for channel Headspace
# Error: API response is missing expected keys for channel Mindfulous
# Error: API response is missing expected keys for channel Breathe For Change
# Error: API response is missing expected keys for channel alberta mind
# Error: API response is missing expected keys for channel Chibs Meditation
# Error: API response is missing expected keys for channel Chibs Meditation
# Error: API response is missing expected keys for channel The Telegraph
# Error: API response is missing expected keys for channel Carl Pullein
# Error: API response is missing expected keys for channel ProjectManager
# Error: API response is missing expected keys for channel SUCCESS INSIDER
# Error: API response is missing expected keys for channel Teamly
# Error: API response is missing expected keys for channel TED-Ed
# Error: API response is missing expected keys for channel Harvs Air Service
# Error: API response is missing expected keys for channel Project Management Companion
# Error: API response is missing expected keys for channel monday.com
# Error: API response is missing expected keys for channel Quimbee
# Error: API response is missing expected keys for channel Automation Anywhere
# Error: API response is missing expected keys for channel Kandy G
# Error: API response is missing expected keys for channel Keep Productive with ClickUp
# Error: API response is missing expected keys for channel Quimbee
# Error: API response is missing expected keys for channel Quimbee
# Error: API response is missing expected keys for channel Sravan Konde
# Error: API response is missing expected keys for channel VMware vSphere
# Error: API response is missing expected keys for channel Placement Interview
# Error: API response is missing expected keys for channel IST Networks
# Error: API response is missing expected keys for channel Automation Anywhere
# Error: API response is missing expected keys for channel Paul Minors
# Error: API response is missing expected keys for channel Quimbee
# Error: API response is missing expected keys for channel Asana
# Error: API response is missing expected keys for channel Quimbee
# Error: API response is missing expected keys for channel How to Simple
# Error: API response is missing expected keys for channel Splunk
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel TED
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Aetna
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Psych Hub
# Error: API response is missing expected keys for channel St. Joseph's Health Care London
# Error: API response is missing expected keys for channel NCCIH
# Error: API response is missing expected keys for channel Scott Todnem | Mindful Teaching
# Error: API response is missing expected keys for channel The Tavistock and Portman NHS Foundation Trust
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Dr. Nicole Cain, ND, MA
# Error: API response is missing expected keys for channel Independence Blue Cross
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Government of Jersey
# Error: API response is missing expected keys for channel North Bristol NHS Trust
# Error: API response is missing expected keys for channel Policy Research Associates, Inc.
# Error: API response is missing expected keys for channel Movement & Creativity
# Error: API response is missing expected keys for channel Mental Health Center Kids
# Error: API response is missing expected keys for channel NCERT OFFICIAL
# Error: API response is missing expected keys for channel Cleveland Clinic
# Error: API response is missing expected keys for channel Let's TEACH
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Nashville Public Television
# Error: API response is missing expected keys for channel SingHealth
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel TED
# Error: API response is missing expected keys for channel TED
# Error: API response is missing expected keys for channel Practical Wisdom - Interesting Ideas
# Error: API response is missing expected keys for channel CareerAddict
# Error: API response is missing expected keys for channel Jennifer Brick
# Error: API response is missing expected keys for channel Thomas Frank
# Error: API response is missing expected keys for channel Brian Tracy
# Error: API response is missing expected keys for channel LifeUpGuru \ HEALTH CARE
# Error: API response is missing expected keys for channel The School of Life
# Error: API response is missing expected keys for channel Brian Tracy
# Error: API response is missing expected keys for channel Tutorialspoint
# Error: API response is missing expected keys for channel Traversy Media
# Error: API response is missing expected keys for channel Teal Swan
# Error: API response is missing expected keys for channel Now moment
# Error: API response is missing expected keys for channel A Life After Layoff
# Error: API response is missing expected keys for channel The Yoga Institute
# Error: API response is missing expected keys for channel Ali Abdaal - Appendix
# Error: API response is missing expected keys for channel Elevate Career Freedom!
# Error: API response is missing expected keys for channel The Manifold Hustle
# Error: API response is missing expected keys for channel Tutorialspoint
# Error: API response is missing expected keys for channel Keiana Byfield
# Error: API response is missing expected keys for channel KING 5 Seattle
# Error: API response is missing expected keys for channel Kristen Marie
# Error: API response is missing expected keys for channel Remodelers Advantage Inc.
# Error: API response is missing expected keys for channel The Futur
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Philip VanDusen
# Error: API response is missing expected keys for channel Rachel How
# Error: API response is missing expected keys for channel OCD and Anxiety
# Error: API response is missing expected keys for channel Jaiden Animations
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Eckhart Tolle
# Error: API response is missing expected keys for channel Dr. Tracey Marks
# Error: API response is missing expected keys for channel Dr. Tracey Marks
# Error: API response is missing expected keys for channel Figure 1
# Error: API response is missing expected keys for channel Jennifer George
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel bignoknow - Noah Thomas
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Med School Insiders
# Error: API response is missing expected keys for channel University of California Television (UCTV)
# Error: API response is missing expected keys for channel Cathy Norris
# Error: API response is missing expected keys for channel IndieAndy
# Error: API response is missing expected keys for channel Icahn School of Medicine
# Error: API response is missing expected keys for channel Kati Morton
# Error: API response is missing expected keys for channel ATRIUM Collaborative
# Error: API response is missing expected keys for channel Dr. Tracey Marks
# Error: API response is missing expected keys for channel Therapy in a Nutshell
# Error: API response is missing expected keys for channel AbrahamThePharmacist
# Error: API response is missing expected keys for channel Parent Lab
# Error: API response is missing expected keys for channel Doc Snipes
# Error: API response is missing expected keys for channel Dragonfly Mental Health
# Error: API response is missing expected keys for channel Ben Meijer
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel The Aspen Institute
# Error: API response is missing expected keys for channel Doc Snipes
# Error: API response is missing expected keys for channel Kristie Pham
# Error: API response is missing expected keys for channel Ryan White HIV/AIDS Program TargetHIV
# Error: API response is missing expected keys for channel Shannon Segres Yorkman
# Error: API response is missing expected keys for channel Mayo Proceedings
# Error: API response is missing expected keys for channel Woebot Health
# Error: API response is missing expected keys for channel NBC News
# Error: API response is missing expected keys for channel The Outcome
# Error: API response is missing expected keys for channel Hindu Community Institute
# Error: API response is missing expected keys for channel Keep On Coding
# Error: API response is missing expected keys for channel Adam Mitchell-Hardt
# Error: API response is missing expected keys for channel The Hidden Profit
# Error: API response is missing expected keys for channel Business Central
# Error: API response is missing expected keys for channel Management Tutorials
# Error: API response is missing expected keys for channel Dianne Sullivan
# Error: API response is missing expected keys for channel Jay Shetty
# Error: API response is missing expected keys for channel CNBC Make It
# Error: API response is missing expected keys for channel American Medical Association (AMA)
# Error: API response is missing expected keys for channel CBS Mornings
# Error: API response is missing expected keys for channel GDEON S.A.
# Error: API response is missing expected keys for channel Association of Salaried Medical Specialists
# Error: API response is missing expected keys for channel B2E Automation
# Error: API response is missing expected keys for channel Mayo Proceedings
# Error: API response is missing expected keys for channel The Outcome
# Error: API response is missing expected keys for channel Arthur Doler
# Error: API response is missing expected keys for channel American Medical Association (AMA)
# Error: API response is missing expected keys for channel CBS Miami
# Error: API response is missing expected keys for channel SUCCESS Magazine
# Error: API response is missing expected keys for channel 8 News NOW Las Vegas
# Error: API response is missing expected keys for channel Crash Course MBA
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Great Leadership With Jacob Morgan
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Homewood Health
# Error: API response is missing expected keys for channel The Lavin Agency Speakers Bureau
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Daren Martin, PhD | Motivational Keynote Speaker
# Error: API response is missing expected keys for channel Darin Rowell EdD
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel Qualia Counselling Services
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Justin McClung
# Error: API response is missing expected keys for channel Muniba Irfan
# Error: API response is missing expected keys for channel TMJ4 News
# Error: API response is missing expected keys for channel Customer Service Training by Telephone Doctor
# Error: API response is missing expected keys for channel CSR Training Team Sabbagh
# Error: API response is missing expected keys for channel Denise Griffitts
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel ASAP
# Error: API response is missing expected keys for channel Be a Dreamer
# Error: API response is missing expected keys for channel Flocabulary
# Error: API response is missing expected keys for channel Kara Ronin
# Error: API response is missing expected keys for channel Telosity
# Error: API response is missing expected keys for channel SCNetwork Canada
# Error: API response is missing expected keys for channel University of South Australia
# Error: API response is missing expected keys for channel Sigmoid Curve Consulting Group - Experts in Change Leadership
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel UNSW Community
# Error: API response is missing expected keys for channel Mr Bizcuit
# Error: API response is missing expected keys for channel Bite-sized Philosophy
# Error: API response is missing expected keys for channel TED Audio Collective
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Anjana Arun
# Error: API response is missing expected keys for channel Sigmoid Curve Consulting Group - Experts in Change Leadership
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel After Skool
# Error: API response is missing expected keys for channel IT Revolution
# Error: API response is missing expected keys for channel TED-Ed
# Error: API response is missing expected keys for channel The School of Life
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel Adriana Girdler
# Error: API response is missing expected keys for channel TED
# Error: API response is missing expected keys for channel Jennifer Brick
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Demystifying Medicine McMaster
# Error: API response is missing expected keys for channel PhilosophyInsights
# Error: API response is missing expected keys for channel Ian Goodman
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel PragerU
# Error: API response is missing expected keys for channel The Art of Improvement
# Error: API response is missing expected keys for channel MulliganBrothers
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Leicestershire Partnership NHS Trust
# Error: API response is missing expected keys for channel BBC Ideas
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel Kati Morton
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel Black Dog Institute
# Error: API response is missing expected keys for channel Center on the Developing Child at Harvard University
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel How to ADHD
# Error: API response is missing expected keys for channel Harvard Online
# Error: API response is missing expected keys for channel Action for Happiness
# Error: API response is missing expected keys for channel TED
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Chrystal Evans Hurst
# Error: API response is missing expected keys for channel GFDRR
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Action for Happiness
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Center on the Developing Child at Harvard University
# Error: API response is missing expected keys for channel ProTradeCraft
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel MedCircle
# Error: API response is missing expected keys for channel Cleveland Clinic
# Error: API response is missing expected keys for channel Hallmark Business Connections
# Error: API response is missing expected keys for channel Myra Golden
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Breed Hope
# Error: API response is missing expected keys for channel Brian Nox
# Error: API response is missing expected keys for channel Matthew Hussey
# Error: API response is missing expected keys for channel Empath and Narcissist
# Error: API response is missing expected keys for channel The Gottman Institute
# Error: API response is missing expected keys for channel MedCircle
# Error: API response is missing expected keys for channel Diana Simon Psihoterapeut
# Error: API response is missing expected keys for channel Six Seconds, The Emotional Intelligence Network
# Error: API response is missing expected keys for channel Christine Dang
# Error: API response is missing expected keys for channel Moti Verse
# Error: API response is missing expected keys for channel The School of Life
# Error: API response is missing expected keys for channel Brannon Patrick
# Error: API response is missing expected keys for channel Alan Robarge / Attachment Trauma Therapist
# Error: API response is missing expected keys for channel E-Gen Global Education
# Error: API response is missing expected keys for channel Smile and Learn - English
# Error: API response is missing expected keys for channel Empath Stories
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel BRAINY DOSE
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel The School of Life
# Error: API response is missing expected keys for channel Andrew Huberman
# Error: API response is missing expected keys for channel Communication Coach Alexander Lyon
# Error: API response is missing expected keys for channel Be Well Wisdom
# Error: API response is missing expected keys for channel Cityline
# Error: API response is missing expected keys for channel Meghan Livingstone
# Error: API response is missing expected keys for channel How to Adult
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Simple Happy Zen
# Error: API response is missing expected keys for channel The Uma Show
# Error: API response is missing expected keys for channel Yoga with Kassandra
# Error: API response is missing expected keys for channel Elicia Goguen
# Error: API response is missing expected keys for channel Malama Life
# Error: API response is missing expected keys for channel Allina Health
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Connie Riet
# Error: API response is missing expected keys for channel Headspace
# Error: API response is missing expected keys for channel National Association of Independent Schools (NAIS)
# Error: API response is missing expected keys for channel Jamie Mastroberti MS, RDN - Sidebar Nutrition
# Error: API response is missing expected keys for channel Alyssa McKay
# Error: API response is missing expected keys for channel The Girl Gone Green
# Error: API response is missing expected keys for channel Elite Healers Sports Massage NYC
# Error: API response is missing expected keys for channel The Green Witch
# Error: API response is missing expected keys for channel Everyday Health
# Error: API response is missing expected keys for channel Wellspring Cancer Support
# Error: API response is missing expected keys for channel headspace by Stride
# Error: API response is missing expected keys for channel Network of the National Library of Medicine [NNLM]
# Error: API response is missing expected keys for channel Family Caregiver Alliance
# Error: API response is missing expected keys for channel Live Fertile
# Error: API response is missing expected keys for channel Hope and Healing Center & Institute
# Error: API response is missing expected keys for channel Elaine Oyang
# Error: API response is missing expected keys for channel Med School Insiders
# Error: API response is missing expected keys for channel Faisal N. Khan 1ExtraordinaryLife
# Error: API response is missing expected keys for channel Demystifying Medicine McMaster
# Error: API response is missing expected keys for channel Private Practice Skills
# Error: API response is missing expected keys for channel Columbia University Irving Medical Center
# Error: API response is missing expected keys for channel Med School Insiders
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel kounsel
# Error: API response is missing expected keys for channel The Aspen Institute
# Error: API response is missing expected keys for channel MMC Medical Education
# Error: API response is missing expected keys for channel HLC Healthy Lifestyle Center
# Error: API response is missing expected keys for channel Antonio J. Webb, M.D.
# Error: API response is missing expected keys for channel Shaimaa Ashry
# Error: API response is missing expected keys for channel Network of the National Library of Medicine [NNLM]
# Error: API response is missing expected keys for channel Healthier Workforce Center
# Error: API response is missing expected keys for channel Association for Applied Sport Psychology
# Error: API response is missing expected keys for channel NeuroCareAI
# Error: API response is missing expected keys for channel Psychology Demystified
# Error: API response is missing expected keys for channel ASE360
# Error: API response is missing expected keys for channel Samuel Merritt University
# Error: API response is missing expected keys for channel Arthur Doler
# Error: API response is missing expected keys for channel UCLA Health
# Error: API response is missing expected keys for channel Grand Rounds in Urology
# Error: API response is missing expected keys for channel Figure 1
# Error: API response is missing expected keys for channel Interview Advice from the Scharff Tank
# Error: API response is missing expected keys for channel BJGP
# Error: API response is missing expected keys for channel Stephen Goldberg
# Error: API response is missing expected keys for channel Branding Simple Channel
# Error: API response is missing expected keys for channel TED
# Error: API response is missing expected keys for channel The Outcome
# Error: API response is missing expected keys for channel Steel Trap
# Error: API response is missing expected keys for channel Statistics and Research with Dr. Wendi L. Benson
# Error: API response is missing expected keys for channel William Obenauer
# Error: API response is missing expected keys for channel Alux.com
# Error: API response is missing expected keys for channel Xing Rong
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel Karina Dvir
# Error: API response is missing expected keys for channel Bernd Geropp
# Error: API response is missing expected keys for channel The Outcome
# Error: API response is missing expected keys for channel Management Tutorials
# Error: API response is missing expected keys for channel Troy Dacumos
# Error: API response is missing expected keys for channel Sprouts
# Error: API response is missing expected keys for channel Betsy Allen-Manning, Leadership Speaker
# Error: API response is missing expected keys for channel GreggU
# Error: API response is missing expected keys for channel OpenLearn from The Open University
# Error: API response is missing expected keys for channel Vishal Khandol
# Error: API response is missing expected keys for channel Powerful Pill
# Error: API response is missing expected keys for channel Sukoon_3.0
# Error: API response is missing expected keys for channel DWIVEDI GUIDANCE
# Error: API response is missing expected keys for channel Andrew Huberman
# Error: API response is missing expected keys for channel The Office
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Go H.A.M. Lifestyle vlogs
# Error: API response is missing expected keys for channel Sydney Watson
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel The Warrior Mindset
# Error: API response is missing expected keys for channel John G. Self
# Error: API response is missing expected keys for channel Lisa Bilyeu
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Everything Sherry
# Error: API response is missing expected keys for channel vpro documentary
# Error: API response is missing expected keys for channel Nikki Bush, Business Speaker
# Error: API response is missing expected keys for channel Aware Super
# Error: API response is missing expected keys for channel UH Class OET
# Error: API response is missing expected keys for channel UH Class OET
# Error: API response is missing expected keys for channel GreggU
# Error: API response is missing expected keys for channel Mike Chang
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel alejandro boccini
# Error: API response is missing expected keys for channel The Kelly Clarkson Show
# Error: API response is missing expected keys for channel WGN News
# Error: API response is missing expected keys for channel John Spencer
# Error: API response is missing expected keys for channel Barbara Heffernan
# Error: API response is missing expected keys for channel What's up, Olivinha?
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Doc Snipes Addiction Recovery
# Error: API response is missing expected keys for channel Doc Snipes Addiction Recovery
# Error: API response is missing expected keys for channel Doc Snipes
# Error: API response is missing expected keys for channel Doc Snipes Addiction Recovery
# Error: API response is missing expected keys for channel Doc Snipes Addiction Recovery
# Error: API response is missing expected keys for channel Retention Guru
# Error: API response is missing expected keys for channel Just Passing Time
# Error: API response is missing expected keys for channel Douglas Bloch
# Error: API response is missing expected keys for channel Psych2Go
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel XRP News
# Error: API response is missing expected keys for channel Transforming Education
# Error: API response is missing expected keys for channel Lucas Capalbo
# Error: API response is missing expected keys for channel Administration for Community Living
# Error: API response is missing expected keys for channel MSFTImagine
# Error: API response is missing expected keys for channel Andrew Sillitoe
# Error: API response is missing expected keys for channel Doc Snipes
# Error: API response is missing expected keys for channel SUCCESS CHASERS
# Error: API response is missing expected keys for channel Mastery Muse - Marika
# Error: API response is missing expected keys for channel celestial_fit
# Error: API response is missing expected keys for channel Skills Academia
# Error: API response is missing expected keys for channel The Yoga Institute
# Error: API response is missing expected keys for channel Peter Hudson Golf
# Error: API response is missing expected keys for channel CETL at University of Arizona Global Campus
# Error: API response is missing expected keys for channel Quotes Life
# Error: API response is missing expected keys for channel The Art of Improvement
# Error: API response is missing expected keys for channel Andrew Huberman
# Error: API response is missing expected keys for channel TED
# Error: API response is missing expected keys for channel Andrew Huberman
# Error: API response is missing expected keys for channel PhilosophyInsights
# Error: API response is missing expected keys for channel DEEP MOTIVATION
# Error: API response is missing expected keys for channel Brian Tracy
# Error: API response is missing expected keys for channel EL Education
# Error: API response is missing expected keys for channel Ali Abdaal
# Error: API response is missing expected keys for channel Max Maher
# Error: API response is missing expected keys for channel Breathe and Bloom
# Error: API response is missing expected keys for channel Brian Tracy
# Error: API response is missing expected keys for channel Ziglar Inc.
# Error: API response is missing expected keys for channel Kleiner Perkins
# Error: API response is missing expected keys for channel Understanding Success
# Error: API response is missing expected keys for channel Educational Fuel
# Error: API response is missing expected keys for channel CBC Kids
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel RocketKids
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel Laugh & Learn
# Error: API response is missing expected keys for channel Better Than Yesterday
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel DEEP MOTIVATION
# Error: API response is missing expected keys for channel 2 Minute Classroom
# Error: API response is missing expected keys for channel The Success Formula
# Error: API response is missing expected keys for channel Counselor Carl
# Error: API response is missing expected keys for channel Tire Review
# Error: API response is missing expected keys for channel Shop Owner
# Error: API response is missing expected keys for channel Valerie Neenan
# Error: API response is missing expected keys for channel tonneson + co
# Error: API response is missing expected keys for channel Institute of Singapore Chartered Accountants
# Error: API response is missing expected keys for channel Continual Growth
# Error: API response is missing expected keys for channel Gina Schreck
# Error: API response is missing expected keys for channel Joseph Meyer
# Error: API response is missing expected keys for channel Spaulding Academy & Family Services
# Error: API response is missing expected keys for channel Just Being Curious By Sakshi
# Error: API response is missing expected keys for channel Edward Shehab
# Error: API response is missing expected keys for channel Spaulding Academy & Family Services
# Error: API response is missing expected keys for channel FreeMedEducation
# Error: API response is missing expected keys for channel Montana State University
# Error: API response is missing expected keys for channel Virgilio Boado, PhD
# Error: API response is missing expected keys for channel What To Expect
# Error: API response is missing expected keys for channel ACM - Academy of Country Music
# Error: API response is missing expected keys for channel TTU School of Veterinary Medicine
# Error: API response is missing expected keys for channel Engrave - Awards & More
# Error: API response is missing expected keys for channel U.S. Senator Roger Wicker
# Error: API response is missing expected keys for channel Chris LoCurto
# Error: API response is missing expected keys for channel Tire Review
# Error: API response is missing expected keys for channel Inktel Contact Center Solutions
# Error: API response is missing expected keys for channel BARUDAN Europe
# Error: API response is missing expected keys for channel FirstCry Parenting
# Error: API response is missing expected keys for channel SBN TV
# Error: API response is missing expected keys for channel SBN TV
# Error: API response is missing expected keys for channel SBN TV
# Error: API response is missing expected keys for channel Bally Sports Midwest
# Error: API response is missing expected keys for channel United Nations
# Error: API response is missing expected keys for channel World Government Summit
# Error: API response is missing expected keys for channel Jess Charrier
# Error: API response is missing expected keys for channel Sarah Madore
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel The Myers-Briggs Company
# Error: API response is missing expected keys for channel Harmonious Minds
# Error: API response is missing expected keys for channel Simon Sinek
# Error: API response is missing expected keys for channel Alexander Emmanual Sandalis
# Error: API response is missing expected keys for channel Dani Christine
# Error: API response is missing expected keys for channel Barcelona Activa
# Error: API response is missing expected keys for channel The Workplace Therapist Show
# Error: API response is missing expected keys for channel Pollocks Intelli School
# Error: API response is missing expected keys for channel Ohio Department of Education
# Error: API response is missing expected keys for channel ParentWiselb
# Error: API response is missing expected keys for channel Saïd Business School, University of Oxford
# Error: API response is missing expected keys for channel International Peace Institute
# Error: API response is missing expected keys for channel Naphtali Hoff
# Error: API response is missing expected keys for channel United Nations Industrial Development Organization (UNIDO)
# Error: API response is missing expected keys for channel TEDx Talks
# Error: API response is missing expected keys for channel ANISA TECH
# Error: API response is missing expected keys for channel Gania Hona
# Error: API response is missing expected keys for channel PTF Chat & Learns

# %%
# Print the modified dataframe with the subscriber count
raw_youtube_data.head(2)
# Out:
#             Search_Term                                    Video_URL  \
# 0  Emotional exhaustion  https://www.youtube.com/watch?v=tVhEz_jceuU
# 1  Emotional exhaustion  https://www.youtube.com/watch?v=CDvnw8eOjFQ
#
#                                   Video_Title Channel_Name Total_Subscribers  \
# 0  8 Things That Lead To Emotional Exhaustion     Psych2Go           unknown
# 1                7 Signs of Emotional Burnout     Psych2Go           unknown
#
#   Total_Views Total_Likes  Total_Dislikes Total_Comments  \
# 0      183411       10798               0            726
# 1     2255329       99671               0           8098
#
#                                    Video_Description  \
# 0  Ever feel like life is stressful every single ...
# 1  Emotional burnout is defined as a negative sta...
#
#   Total_times_User_added_to_favorites Video_Length Video_Category  \
# 0                                   0     00:06:01      Education
# 1                                   0     00:06:14      Education
#
#                                           Video_Tags Age_Restrictions  \
# 0  [emotional exhaustion, 8 Things That Lead To E...               NA
# 1  [emotional burnout, emotional burnout symptoms...               NA
#
#           License Captions_Available
# 0  creativeCommon                 NA
# 1  creativeCommon                 NA

# %%
len(raw_youtube_data)
# Out:
# 630

# %%
raw_youtube_data['search_term_video_url'] = raw_youtube_data['Search_Term'] + '_' + raw_youtube_data['Video_URL']

# %%
unique_values = raw_youtube_data['search_term_video_url'].unique()

# print the unique values
print(len(unique_values))
# Out:
# 630

# %%
raw_youtube_data['domain'] = ''

emotional_exhaustion_keywords = [
    "Emotional exhaustion",
    "Stress reduction and burnout",
    "Burnout and emotions",
    "Mindfulness and burnout",
    "Workload management",
    "Emotional well-being techniques",
    "Work-life balance techniques"
]

depersonalization_keywords = [
    "Depersonalization and burnout",
    "Job satisfaction and burnout",
    "Building empathy in the workplace",
    "Managing workplace cynicism",
    "Resilience building",
    "Empathy and emotional connection",
    "Self-care practices"
]

personal_achievement_keywords = [
    "Personal accomplishment and burnout",
    "Motivation and job satisfaction",
    "Empowerment self at work",
    "Enhancing self-efficacy",
    "Goal setting and achievement",
    "Recognizing achievements and milestones",
    "Fostering growth and development"
]

raw_youtube_data.loc[raw_youtube_data['Search_Term'].isin(emotional_exhaustion_keywords), 'domain'] = 'Emotional exhaustion'
raw_youtube_data.loc[raw_youtube_data['Search_Term'].isin(depersonalization_keywords), 'domain'] = 'Depersonalization'
raw_youtube_data.loc[raw_youtube_data['Search_Term'].isin(personal_achievement_keywords), 'domain'] = 'Personal achievement'

# %%
raw_youtube_data.to_csv('yt_videos_meta.csv', index=False)

# %%
raw_youtube_data_db = raw_youtube_data.rename(columns={
    'Search_Term': 'search_term',
    'Video_URL': 'video_url',
    'Video_Title': 'video_title',
    'Channel_Name': 'channel_name',
    'Total_Subscribers': 'total_subscribers',
    'Total_Views': 'total_views',
    'Total_Likes': 'total_likes',
    'Total_Dislikes': 'total_dislikes',
    'Total_Comments': 'total_comments',
    'Video_Description': 'video_desc',
    'Total_times_User_added_to_favorites': 'total_times_User_added_to_favorites',
    'Video_Length': 'video_length',
    'Video_Category': 'video_category',
    'Video_Tags': 'video_tag',
    'Age_Restrictions': 'age_restrictions',
    'License': 'license',
    'Captions_Available': 'captions_available',
    'search_term_video_url':'search_term_video_url',
    'domain':'domain'
})

# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

# Connect to the PostgreSQL database
host = '173.249.1.23'
port = '5432'
db = 'dj_project'
user = 'postgres'
password = 'Password'
conn_str = f'postgresql://{user}:{password}@{host}:{port}/{db}'
engine = create_engine(conn_str)


# Write the dataframe to a PostgreSQL table
table_name = 'youtube_videos_meta'
raw_youtube_data_db.to_sql(table_name, engine, if_exists='append', index=False)
# Out:
# 630

# %% [markdown]
# # Part 2 : Created a new Dataframe (raw_youtube_data_comments) with the list of URLs and associated comments

# %%
# Load the previously saved youtube data
raw_youtube_data = raw_youtube_data

# %%
raw_youtube_data_comments = pd.DataFrame(columns=['Video_URL', 'Comment'])
videos_with_disabled_comments = []

# %%
for url in raw_youtube_data['Video_URL']:
    video_id = url.split('=')[1]
    video_response = youtube.videos().list(
        part='snippet,statistics',
        id=video_id
    ).execute()

    try:
        # Check if comments are disabled for the video
        comment_count = video_response['items'][0]['statistics'].get('commentCount', None)
        if comment_count is None or comment_count == '0':
            print(f'Comments are disabled for {url}')
            videos_with_disabled_comments.append(url)
            raw_youtube_data_comments = raw_youtube_data_comments.append({'Video_URL': url,
                                                                          'Comment': 'Video owner has disabled comments on their video'},
                                                                         ignore_index=True)
            continue

        # Use the API to get the comments for the video
        comments = []
        next_page_token = None

        while True:
            comment_response = youtube.commentThreads().list(
                part='snippet',
                videoId=video_id,
                maxResults=100,
                pageToken=next_page_token
            ).execute()

            # Extract the comments from the response
            for item in comment_response['items']:
                comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
                comments.append(comment)

            # Check if there are more comments
            if 'nextPageToken' in comment_response:
                next_page_token = comment_response['nextPageToken']
            else:
                break

        # Save the comments to the DataFrame
        for comment in comments:
            raw_youtube_data_comments = raw_youtube_data_comments.append({'Video_URL': url,
                                                                          'Comment': comment},
                                                                         ignore_index=True)

    except HttpError as error:
        print(f'An HTTP error occurred: {error}')
        continue

    except KeyError:
        print(f'Comments are disabled for {url}')
        raw_youtube_data_comments = raw_youtube_data_comments.append({'Video_URL': url,
                                                                      'Comment': 'Video owner has disabled comments on their video'},
                                                                     ignore_index=True)
        continue
# Out:
# Comments are disabled for https://www.youtube.com/watch?v=ZUw5_EeO0xc
# Comments are disabled for https://www.youtube.com/watch?v=C1ntSs5CgNQ
# Comments are disabled for https://www.youtube.com/watch?v=ceIR-g4wU4Y
# Comments are disabled for https://www.youtube.com/watch?v=aaVJrATVe1w
# Comments are disabled for https://www.youtube.com/watch?v=BAsGjOxriIk
# Comments are disabled for https://www.youtube.com/watch?v=7KE6OTHiw-U
# Comments are disabled for https://www.youtube.com/watch?v=LfPY4OfMOCg
# Comments are disabled for https://www.youtube.com/watch?v=4VztJH2k99E
# Comments are disabled for https://www.youtube.com/watch?v=HXA330433uI
# Comments are disabled for https://www.youtube.com/watch?v=NsyO7NQy0fE
# Comments are disabled for https://www.youtube.com/watch?v=VGBQ_PjQ890
# Comments are disabled for https://www.youtube.com/watch?v=jO-vcvhKC4I
# Comments are disabled for https://www.youtube.com/watch?v=BNajuzhEC_A
# Comments are disabled for https://www.youtube.com/watch?v=Po9katvlldw
# Comments are disabled for https://www.youtube.com/watch?v=XTvaLgQvvi4
# Comments are disabled for https://www.youtube.com/watch?v=mdhTwua29cg
# Comments are disabled for https://www.youtube.com/watch?v=LBhRlbLoCBo
# Comments are disabled for https://www.youtube.com/watch?v=AUs3pYa5MtY
# Comments are disabled for https://www.youtube.com/watch?v=VXJKmdU67C8
# Comments are disabled for https://www.youtube.com/watch?v=i73zh1fdDG0
# Comments are disabled for https://www.youtube.com/watch?v=Qt7FttIi0Ew
# Comments are disabled for https://www.youtube.com/watch?v=bmVrbqsgGyM
# Comments are disabled for https://www.youtube.com/watch?v=s4G5F1QMAOE
# Comments are disabled for https://www.youtube.com/watch?v=kLG7EZ4h9Hk
# Comments are disabled for https://www.youtube.com/watch?v=7PsBtDWBb1M
# Comments are disabled for https://www.youtube.com/watch?v=-2ao_9-qNF4
# Comments are disabled for https://www.youtube.com/watch?v=OPk3ND___NM
# Comments are disabled for https://www.youtube.com/watch?v=fLY_ekeJh9U
# Comments are disabled for https://www.youtube.com/watch?v=Emhv4t63jyI
# Comments are disabled for https://www.youtube.com/watch?v=UqrkMfLVQow
# Comments are disabled for https://www.youtube.com/watch?v=92LpqFXX3fs
# Comments are disabled for https://www.youtube.com/watch?v=Nyw1GD8YuJk
# Comments are disabled for https://www.youtube.com/watch?v=tXtyeSIY1_Y
# Comments are disabled for https://www.youtube.com/watch?v=iL9DNpCSRjc
# Comments are disabled for https://www.youtube.com/watch?v=b08kTApY-MM
# Comments are disabled for https://www.youtube.com/watch?v=RRX-dFpS4IU
# Comments are disabled for https://www.youtube.com/watch?v=_ZyHpyZRCow
# Comments are disabled for https://www.youtube.com/watch?v=VGQkZeg1Dro
# Comments are disabled for https://www.youtube.com/watch?v=5hN-KvxUayg
# Comments are disabled for https://www.youtube.com/watch?v=GZUDtz9nxqI

# %%
raw_youtube_data_comments.head()
# Out:
#                                      Video_URL  \
# 0  https://www.youtube.com/watch?v=tVhEz_jceuU
# 1  https://www.youtube.com/watch?v=tVhEz_jceuU
# 2  https://www.youtube.com/watch?v=tVhEz_jceuU
# 3  https://www.youtube.com/watch?v=tVhEz_jceuU
# 4  https://www.youtube.com/watch?v=tVhEz_jceuU
#
#                                              Comment
# 0     Are you already feeling emotionally exhausted?
# 1                           her voice maks me sleepy
# 2  you should put an ASMR warning. i want to puke...
# 3                              I just started crying
# 4                                               💔😢🙁😭

# %%
mask = raw_youtube_data_comments['Video_URL'].str.startswith('https://www.youtube.com/wa')

# %%
print(len(mask))
# Out:
# 316581

# %%
raw_youtube_data_comments.to_csv('video_comments.csv')

# %%
# Write the dataframe to a PostgreSQL table
table_name = 'yt_vid_comments'
raw_youtube_data_comments.to_sql(table_name, engine, if_exists='append', index=False)
# Out:
# 581

# %%
print("Total number of comments downloaded:",
      len(raw_youtube_data_comments))
# Out:
# Total number of comments downloaded: 316581

# %%
# End the timer
end_time = datetime.datetime.now()

# %%
# Calculate the total time taken to run the notebook
elapsed_time  = end_time - start_time

# %%
# Check if the elapsed_time object is a timedelta object
if isinstance(elapsed_time, datetime.timedelta):
    # Print the total time taken in hh:mm:ss format
    print("Elapsed time (hh:mm:ss):", str(elapsed_time))
else:
    print("Error: elapsed_time object is not a timedelta object")
# Out:
# Elapsed time (hh:mm:ss): 0:20:01.333568

# %%
emotional_keywords = [
    "Overcoming emotional exhaustion at work",
    "Coping with people-related work stress",
    "Managing work-induced breakdown",
    "Reducing frustration at work",
    "Preventing excessive workload",
    "Stress management in client-facing roles",
    "Building resilience in high-stress environments"
]

professions = [
    'Sales Executive',
    'Nursing Staff',
    'Customer Service Representative',
    'Marketing Professionals'
]

age_groups = ['young', 'middle-aged', 'elderly']

genders = ['Female', 'Male']

combinations = []

for keyword in emotional_keywords:
    for gender in genders:
        for age_group in age_groups:
            for profession in professions:
                combination = keyword + " among " + gender + " " + age_group + " " + profession
                combinations.append(combination)

# Print the list of combinations
for combination in combinations:
    print(combination)
